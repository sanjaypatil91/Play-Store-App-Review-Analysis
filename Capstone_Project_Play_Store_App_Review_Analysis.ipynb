# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaypatil91/Play-Store-App-Review-Analysis/blob/main/Capstone_Project_Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Play Store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA ( Exploratory Data Analysis )
# ##### **Contribution**    - Individual
# ##### **Project Carried by** - Sanjay Patil

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Play Store App Review Exploratory Data Analysis (EDA) project is a focused aim to extract valuable insights from user reviews of mobile applications available on the Google Play Store. These user reviews hold a wealth of information that can greatly benefit app developers, marketers, and product managers, aiding them in understanding user sentiments, identifying areas for improvement, and making informed decisions to enhance their apps' performance and user satisfaction. The Play Store App Review EDA project is a journey into the world of user feedback, promising to unlock the hidden gems buried within reviews. Its ultimate goal is to equip app developers and stakeholders with the insights needed to create better app experiences for users.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/sanjaypatil91/Play-Store-App-Review-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Understanding and improving user satisfaction with mobile apps on the Google Play Store is challenging due to the massive number of reviews. We need a way to efficiently analyze these reviews, categorize user sentiments, and pinpoint areas for enhancement, while considering the diverse app categories. The goal is to provide app developers and stakeholders with clear insights and recommendations to enhance app quality and user experiences.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To help app developers and stakeholders improve their mobile applications on the Google Play Store by providing clear insights and recommendations based on user feedback, ultimately enhancing user satisfaction and app quality.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path = "/content/Play Store Data.csv"
df_ps = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df_ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows_count, columns_count = df_ps.shape

print(f"Number of Rows: {rows_count}")
print(f"Number of Columns: {columns_count}")
# Out:
# Number of Rows: 10841
# Number of Columns: 13

# %%
df_ps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information
df_ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df_ps.duplicated().sum()
print(f"Number of duplicate rows are: {duplicate_count}")
# Out:
# Number of duplicate rows are: 483

# %% [markdown]
# #### Missing Values/Null Values Count

# %%
# Missing Values/Null Values Count
missing_values_count = df_ps.isnull().sum()
missing_values_count
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values

missing_values_count.plot(kind='bar', color='blue', rot=90)

plt.title('Missing values in each column')
plt.xlabel('Columns')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Based on the provided synthetic dataset, here's some analysis of the dataset are:
# 1. The dataset appears to contain information about mobile apps, with various columns such as "App," "Category," "Rating," "Reviews," "Size," "Installs," "Type," "Price," "Content Rating," "Genres," "Last Updated," "Current Ver," and "Android Ver."
# 2. The dataset includes some missing values (NaN) / Null values in several columns, as indicated by the count of missing values.
# 3. It is observed that, in "Rating", columns there are 1474 null/missing values, in Type has 1 null value, Content_Rating has 1 null value,Current_Ver has 8 null values and the Android_Ver has 3 null values
# 4. Finally, we visualized on bar plot for better understanding than numerical values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df_ps_dtype = df_ps.dtypes.reset_index()
df_ps_dtype.columns = ["Column", "Dtype"]
df_ps_dtype
# Out:
#             Column    Dtype
# 0              App   object
# 1         Category   object
# 2           Rating  float64
# 3          Reviews   object
# 4             Size   object
# 5         Installs   object
# 6             Type   object
# 7            Price   object
# 8   Content Rating   object
# 9           Genres   object
# 10    Last Updated   object
# 11     Current Ver   object
# 12     Android Ver   object

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **App:** bold text The name of the mobile application available on the Google Play Store.
# 2. **Category**: It describe the category of the apps
# 3. **Rating**: The user rating of the app on a scale from 1 to 5, where a higher rating indicates better user satisfaction.
# 4. **Reviews**: The total number of user reviews and ratings for the app.
# 5. **Size**: The size of the app in terms of storage space required on the user's device. It includes units such as 'M' for megabytes or 'k' for kilobytes.
# 6. **Installs**: The number of times the app has been downloaded and installed.
# 7. **Type**: It states whether an app is free to use or paid.
# 8. **Price**: It gives the price payable to install the app.
# 9.**Content Rating**: The age group or audience for which the app's content is appropriate.
# 10. **Genres**: The specific genre or subcategory to which the app belongs, providing more detailed information about its type, such as 'Puzzle,' 'Communication,' 'Arcade,' etc.
# 11.**Last Updated:** The date when the app was last updated.
# 12. **Current Ver:** The current version number of the app, which helps users and developers keep track of software updates.
# 13. **Android Ver**: This information helps users understand if their devices are compatible with the app.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# To get the data type of columns with index in the dataset
df_ps_dtype = df_ps.dtypes.reset_index()
df_ps_dtype.columns = ["Column", "Dtype"]
# Get all the nonnumeric columns for columns
non_numeric_col = df_ps_dtype[df_ps_dtype['Dtype']=='object']['Column']
#Check Unique Values for each variable/columns.
for col in non_numeric_col:
  print(col)
  print(df_ps[col].unique())
# Out:
# App
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# Category
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# Reviews
# ['159' '967' '87510' ... '603' '1195' '398307']
# Size
# ['19M' '14M' '8.7M' '25M' '2.8M' '5.6M' '29M' '33M' '3.1M' '28M' '12M'
#  '20M' '21M' '37M' '2.7M' '5.5M' '17M' '39M' '31M' '4.2M' '7.0M' '23M'
# ...

# %% [markdown]
# **Inferences :** The df_ps.replace('NaN', np.nan, inplace=True) command is a data cleaning operation that replaces all occurrences of the string "NaN" in the df_ps dataframe object with the special value NaN (not a number). This operation is useful because many datasets, including the automobile dataset from the UCI Machine Learning Repository, may have missing values represented by a certain string or character, such as "?", "NA", or "NaN".

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# **1. Data Inspection:** Explore the dataset to get an initial understanding of its structure, including the number of rows and columns, data types, and missing values.

# %%
def summary_info():
  data=pd.DataFrame(index=df_ps.columns)
  data["datatype"]=df_ps.dtypes
  data["not null values"]=df_ps.count()
  data["null value"]=df_ps.isnull().sum()
  data["unique count"]=df_ps.nunique()
  return data
summary_info()
# Out:
#                datatype  not null values  null value  unique count
# App              object            10841           0          9660
# Category         object            10841           0            34
# Rating          float64             9367        1474            40
# Reviews          object            10841           0          6002
# Size             object            10841           0           462
# Installs         object            10841           0            22
# Type             object            10840           1             3
# Price            object            10841           0            93
# Content Rating   object            10840           1             6
# Genres           object            10841           0           120
# Last Updated     object            10841           0          1378
# Current Ver      object            10833           8          2832
# Android Ver      object            10838           3            33

# %% [markdown]
# **Inferences :** Rating has 1474 null values which contributes, Type has 1 null value, Content_Rating has 1 null value, Current_Ver has 8 null values, Android_Ver has 3 null values.

# %% [markdown]
# **2. Data Cleaning:** It includes the steps like:,handle missing values,remove duplicates, correct errors, Handle outliers and standardize data types,

# %% [markdown]
# **Remove all NaN values from specific columns(like:Rating, Type, Content Rating, Current Ver and Android Ver)**

# %%
columns_to_clean = ['Rating', 'Type', 'Content Rating','Current Ver','Android Ver']
df_ps.dropna(subset=columns_to_clean, inplace=True)
print("After removing the nan values ,number of rows and columns are:", df_ps.shape)
# Out:
# After removing the nan values ,number of rows and columns are: (9360, 13)

# %%
df_ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %% [markdown]
# **3. Handling duplicates:** Identify and remove duplicate rows if they exist.

# %%
# Identify duplicated rows
duplicated_rows = df_ps[df_ps.duplicated()]
duplicated_rows
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
# The number of duplicated rows
print("The number of duplicated rows are:", df_ps.duplicated().sum())
# Out:
# The number of duplicated rows are: 474

# %%
# Remove duplicated rows and keep the first occurrence
df_ps.drop_duplicates(inplace=True)
df_ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# The rating of any app in the play store will be in between 1 and 5. Lets check whether there are any ratings out of this range.

# %%
# Count the values from the rating variable beacause this column contains 1474 NaN values.
df_ps["Rating"].value_counts().shape
# Out:
# (39,)

# %%
# Check if any ratings are outside the range [1, 5]
ratings_outside_range = df_ps[(df_ps['Rating'] < 1) | (df_ps['Rating'] > 5)]
ratings_outside_range
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# Visualization of distribution of rating using histplot and detecting the outliers through boxplot.

# %%
sns.boxplot(x='Rating',data=df_ps)
# Display the plot
plt.show()

# %%
df_ps[['Rating']].describe().round(2).T
# Out:
#          count  mean   std  min  25%  50%  75%  max
# Rating  8886.0  4.19  0.52  1.0  4.0  4.3  4.5  5.0

# %%
sns.histplot(x='Rating', data=df_ps, kde=True)
plt.title("Histplot: Rating vs Count ")
plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ***Inferences: ***
# * The mean of the average ratings (excluding the NaN values) comes to be 4.2.
#
# * The median of the entries (excluding the NaN values) in the 'Rating' column comes to be 4.3. From this we can say that 50% of the apps have an average rating of above 4.3, and the rest below 4.3.
# * From the histplot visualizations, it is clear that the ratings are left skewed.
# * We know that if the variable is skewed, the mean is biased by the values at the far end of the distribution. Therefore, the median is a better representation of the majority of the values in the variable.

# %% [markdown]
# **Note:** Higher the rating for app from the users, higher are the users count.

# %%
# Calculate the median of the column "rating" with NaN values .
median = df_ps['Rating'].median()

# Replace NaN values with the median
df_ps['Rating'].fillna(median, inplace=True)
df_ps

# %% [markdown]
# **Handling the duplicates values from the "App" column**

# %%
# To get the value count of duplicatd app values .
df_ps["App"].value_counts()
# Out:
# ROBLOX                                           9
# 8 Ball Pool                                      7
# Bubble Shooter                                   6
# Helix Jump                                       6
# Zombie Catchers                                  6
#                                                 ..
# Block City Wars + skins export                   1
# KineMaster – Pro Video Editor                    1
# Koi Live Wallpaper                               1
# Geometry Dash Meltdown                           1
# iHoroscope - 2018 Daily Horoscope & Astrology    1
# Name: App, Length: 8190, dtype: int64

# %%
# Inspecting the duplicates values.
df_ps[df_ps["App"]=="ROBLOX"]
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# ...

# %%
# Dropping duplicates from the 'App' column.
df_ps.drop_duplicates(subset = 'App', inplace = True)
df_ps.shape
# Out:
# (8190, 13)

# %%
# Checking whether the duplicates in the 'App' column are taken care of or not
df_ps[df_ps['App']=='ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up

# %% [markdown]
# **4: Data Transformation:** Convert data types: If needed, convert data from one type to another (e.g., strings to numbers).

# %%
# To check the value count in "install" column.
df_ps['Installs'].value_counts()
# Out:
# 1,000,000+        1414
# 100,000+          1094
# 10,000+            986
# 10,000,000+        937
# 1,000+             696
# 5,000,000+         607
# 500,000+           503
# 50,000+            456
# 5,000+             424
# 100+               303
# 50,000,000+        202
# 500+               199
# 100,000,000+       188
# 10+                 69
# 50+                 56
# 500,000,000+        24
# 1,000,000,000+      20
# 5+                   9
# 1+                   3
# Name: Installs, dtype: int64

# %%
# Remove '+' and ',' characters from the 'Installs' column and convert to numeric
df_ps['Installs'] = df_ps['Installs'].str.replace('[+,]', '', regex=True).astype(int)
df_ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Convert the 'Last Updated' column to datetime
df_ps['Last Updated'] = pd.to_datetime(df_ps['Last Updated'])
df_ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# Converting the values in the size column to a same unit of measure(MB).

# %%
df_ps["Size"].value_counts()
# Out:
# Varies with device    1169
# 14M                    148
# 12M                    146
# 13M                    143
# 11M                    143
#                       ...
# 383k                     1
# 454k                     1
# 812k                     1
# 442k                     1
# 619k                     1
# Name: Size, Length: 413, dtype: int64

# %%
# Defining a function to convert all the entries in KB to MB and then converting them to float datatype.
import re
def convert_size_to_numeric(val):
    try:
        if 'M' in val:
            return float(re.sub(r'[^\d.]', '', val))
        elif 'k' in val:
            return round(float(re.sub(r'[^\d.]', '', val)) / 1024, 4)
        else:
            return val
    except ValueError:
        return val

# %%
# The convert_size_to_numeric funtion applied to the size column

df_ps['Size'] = df_ps['Size'].apply(lambda x: convert_size_to_numeric(x))
df_ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159  19.0     10000  Free     0       Everyone
# 1     967  14.0    500000  Free     0       Everyone
# 2   87510   8.7   5000000  Free     0       Everyone
# 3  215644  25.0  50000000  Free     0           Teen
# 4     967   2.8    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df_ps['Size'] = df_ps['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
df_ps['Size'] = df_ps['Size'].apply(lambda x: float(x))

# %%
# Converting the datatype of the values in the reviews column from string to int
df_ps['Reviews'] = df_ps['Reviews'].astype(int)
df_ps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0     10000  Free     0       Everyone
# 1      967  14.0    500000  Free     0       Everyone
# 2    87510   8.7   5000000  Free     0       Everyone
# 3   215644  25.0  50000000  Free     0           Teen
# 4      967   2.8    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df_ps['Price'].value_counts()
# Out:
# 0          7588
# $2.99       109
# $0.99       103
# $4.99        68
# $1.99        59
#            ...
# $1.59         1
# $6.49         1
# $1.29         1
# $299.99       1
# $1.20         1
# Name: Price, Length: 73, dtype: int64

# %%
# Creating a function drop-dollar which dropps the $ symbol if it is present and returns the output which is of float datatype.
def convert_price_to_float(price_str):
    if '$' in price_str:
        return float(price_str.replace('$', ''))
    else:
        return float(price_str)

# %%
# Apply the function to the 'Price' column and create a new 'Price (Float)' column
df_ps['Price'] = df_ps['Price'].apply(convert_price_to_float)

# %%
df_ps[df_ps['Price']!=0].head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
# 476                      Moco+ - Chat, Meet People         DATING     4.2
# 477                                     Calculator         DATING     2.6
#
#      Reviews  Size  Installs  Type  Price Content Rating         Genres  \
# 234    11442   6.8    100000  Paid   4.99       Everyone       Business
# 235    10295  39.0    100000  Paid   4.99       Everyone       Business
# 427    18247   NaN    100000  Paid   3.99       Everyone  Communication
# 476     1545   NaN     10000  Paid   3.99     Mature 17+         Dating
# 477       57   6.2      1000  Paid   6.99       Everyone         Dating
#
#     Last Updated  Current Ver Android Ver        Size (Bytes)
# ...

# %% [markdown]
# **5. Aggregation and summarization:** Aggregate data for analysis, e.g., group by categories and calculate summary statistics.

# %%
df_ps.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  8190.000000  8.190000e+03  7021.000000  8.190000e+03  8190.000000
# mean      4.173321  2.554354e+05    21.767166  9.171613e+06     1.038342
# std       0.536691  1.986309e+06    22.731638  5.827170e+07    16.864040
# min       1.000000  1.000000e+00     0.008300  1.000000e+00     0.000000
# 25%       4.000000  1.260000e+02     4.900000  1.000000e+04     0.000000
# 50%       4.300000  3.009500e+03    13.000000  1.000000e+05     0.000000
# 75%       4.500000  4.391425e+04    31.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %% [markdown]
# ### **Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables**

# %% [markdown]
# #### Chart - 1

# %%
# Create histograms for numeric variables
sns.histplot(data=df_ps, x='Rating', bins=20, kde=True)
plt.title('Distribution of Ratings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer**: The choice of a histogram for visualizing the distribution of 'Rating' is appropriate because it provides a comprehensive view of the data's characteristics and allows for insights into its distribution, central tendency, and spread

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer:** The 'Rating' variable has a mean rating of approximately 4.17, with a minimum of 1.00 and a maximum of 5. The majority of ratings are clustered between 4.00 and 4.50, as indicated by the 25th, 50th (median), and 75th percentiles.This suggests that most apps in the dataset have received high to very high ratings, with relatively few receiving low ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
#Relationship between Reviews and Installs)
sns.scatterplot(data=df_ps, x='Reviews', y='Installs')
plt.title('Relationship between Reviews and Installs')
plt.xlabel('Reviews')
plt.ylabel('Installs')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Each point on the scatterplot represents an app, and its position corresponds to its number of installs and reviews. Here's how you can create and interpret the scatterplot:

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer: 1. Generally, there appears to be a positive relationship between the number of installs and the number of reviews. Apps with more installations tend to have more reviews. 2. he majority of points are clustered in the lower-left part of the plot, indicating that many apps have relatively few installs and reviews. This is typical, as only a few apps achieve very high levels of popularity and reviews. 3. There are some outliers in the upper-right part of the scatterplot, indicating a few apps with extremely high numbers of both installs and reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_ps, x='Category', y='Rating', ci=None)
plt.xticks(rotation=90)
plt.title('Average Rating by Category')
plt.xlabel('Category')
plt.ylabel('Average Rating')
plt.show()
# Out:
# <ipython-input-85-893a3898664c>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_ps, x='Category', y='Rating', ci=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer: This code will create a bar graph showing the average ratings for each category, making it easier to compare ratings across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**: It gives relationship between category of the apps with respect to ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4: Pair Plot

# %%
Rating = df_ps['Rating']
Size = df_ps['Size']
Installs = df_ps['Installs']
Reviews = df_ps['Reviews']
Type = df_ps['Type']
Price = df_ps['Price']

p = sns.pairplot(pd.DataFrame(list(zip(Rating, Size, np.log(Installs), np.log10(Reviews), Price, Type)),
                        columns=['Rating','Size', 'Installs', 'Reviews', 'Price','Type']), hue='Type')
p.fig.suptitle("Pairwise Plot - Rating, Size, Installs, Reviews, Price",x=0.5, y=1.0, fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pairwise Plot - Rating, Size, Installs, Reviews, Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer: A pair plot will display scatter plots for the pairwise combinations of these variables and histograms along the diagonal for the individual variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**: Most of the App are Free. Most of the Paid Apps have Rating around 4
# As the number of installation increases the number of reviews of the particaular app also increases. Most of the Apps are light-weighted.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Line plot (e.g., Trends in Ratings over Time)
df_ps['Last Updated'] = pd.to_datetime(df_ps['Last Updated'])
df_ps['Year'] = df_ps['Last Updated'].dt.year
sns.lineplot(data=df_ps, x='Year', y='Rating', ci=None)
plt.title('Trends in Ratings over Time')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.show()
# Out:
# <ipython-input-91-397af72e9a10>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df_ps, x='Year', y='Rating', ci=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer: Line plots are excellent for showing trends and changes in data over time. They are commonly used in time series analysis to visualize how a variable evolves over a continuous period.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**: By observing the general trend of the line, it can identify the average ratings have been increasing, decreasing, or staying relatively stable over the years.Sudden spikes or drops in the average rating may be indicative of changes in the dataset, such as the inclusion of new apps or removal of old ones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer**: The insights gained from analyzing app rating trends over time can indeed help create a positive business impact if they indicate increasing user satisfaction. However, declining ratings or negative trends can pose challenges and lead to negative growth if not addressed promptly. To mitigate negative impacts, businesses should actively monitor and respond to user feedback, continuously improve app quality, and adapt to changing market conditions to stay competitive.

# %% [markdown]
# #### Chart - 6: Correlation Heatmap

# %%
# Chart - 6 visualization code
#Heatmap:Correlation Matrix)
correlation_matrix = df_ps.corr()
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-92-99c24898aea3>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_ps.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer : The heatmap of the correlation matrix is an effective and widely used visualization technique for exploring and understanding the relationships between variables in a dataset. It helps data analysts and researchers quickly identify patterns, dependencies, and potential multicollinearity issues, making it a valuable tool in the data analysis process.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**: Positive correlations are indicated by warmer colors (e.g., shades of red). For example, if you see a strong positive correlation between 'Reviews' and 'Installs,' it suggests that as the number of installations increases, the number of reviews tends to increase as well. This implies that popular apps tend to receive more reviews. Negative correlations are represented by cooler colors (e.g., shades of blue). If you observe a negative correlation between 'Price' and 'Rating,' it suggests that higher-priced apps tend to receive lower ratings, and vice versa.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer**: The insights from the correlation matrix heatmap can help businesses make informed decisions and take actions that drive positive growth. However, it's crucial to interpret these insights in context, considering causality, data quality, and potential pitfalls. Negative growth can occur if the business misinterprets or misapplies the insights, especially when dealing with negative correlations or multicollinearity. Careful analysis, domain expertise, and a balanced approach to decision-making are essential to maximize the positive impact of these insights on business growth.

# %% [markdown]
# # **Exploring User_review dataframe**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
